# %%
# !pip install tensorflow==2.8.0
# !pip install numpy==1.18.5
# !pip install pandas==1.1.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 29.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 64.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 88.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 92.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 49.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: google-auth-oauthlib
# ...

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import argparse
import os
import tensorflow.keras as keras            #type: ignore
from tensorflow.keras import layers          #type: ignore

# %%
print(f"pandas verison: {pd.__version__}")
print(f"numpy verison: {np.__version__}")
print(f"TensorFlow version: {tf.__version__}")x
print(f"Keras version: {keras.__version__}")
# Out:
# pandas verison: 2.1.4
# numpy verison: 1.26.4
# TensorFlow version: 2.8.0
# Keras version: 2.8.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ori = pd.read_csv('Data-immuno (1).csv')
ori.head()
# Out:
#   LIYDSSLCDL  HLA-B*0702
# 0  FLWGPRALV  HLA-B*0702
# 1  YMDGTMSQV  HLA-A*2402
# 2  YLEPGPVTA  HLA-A*0201
# 3  YMDGTMSQV  HLA-B*0702
# 4  ALLAVGATK  HLA-B*0702

# %%
# !python 'Imunogenisitas.py'--mode "multiple" --intdir "example.csv"--outdir "/content/drive/MyDrive/colab-deepimmuno/Epochfile"
# Out:
# 2024-09-02 06:48:24.269233: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# mode is multiple
# input file is Data-immuno (1).csv
# output will be in /content/drive/MyDrive/colab-deepimmuno/Epochfile
# 2024-09-02 06:48:27.030551: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-09-02 06:48:27.030599: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# ...

# %%
# !python 'Imunogenisitas.py'--mode "single" --epitope "LLMEGVPKSL" --hla "HLA-A*0201"
# Out:
# 2024-08-18 03:50:59.348848: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# mode is single
# queried epitope is HPPLMNVER
# queried HLA is HLA-A*0201
# 2024-08-18 03:51:02.479221: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-08-18 03:51:02.479294: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# ...
